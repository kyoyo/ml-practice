# %% [markdown]
# # 导数
#
# ## 基本法则
#
# - 法则一
# 常数函数的导数为0
#
# - 法则二
# 正整数幂法则 $ \frac{\mathrm{d} }{\mathrm{d} x}x^n = nx^{n-1} $
#
# - 法则三
# 乘常数法则 $ \frac{\mathrm{d} }{\mathrm{dx}}(cu) = c\frac{\mathrm{d} }{\mathrm{dx}} u  $
#
# - 法则四
# 导数和法则 $ \frac{\mathrm{d} }{\mathrm{dx}}(u + v) = \frac{\mathrm{du} }{\mathrm{dx}} + \frac{\mathrm{dv} }{\mathrm{dx}}  $
#
# - 法则五
# 导数的积法则 $ \frac{\mathrm{d} }{\mathrm{dx}}(uv) = u\frac{\mathrm{dv} }{\mathrm{dx}} +  u\frac{\mathrm{dv} }{\mathrm{dx}} $
#
# - 法则六
# 导数的商法则 $ \frac{\mathrm{d} }{\mathrm{dx}}(\frac{u}{v}) = \frac {v\frac{\mathrm{du} }{\mathrm{dx}} - u\frac{\mathrm{dv} }{\mathrm{dx}}} {v^{2}}   $
#
# - 法则七
# 负整数次幂法则 $ \frac{\mathrm{d} }{\mathrm{d} x}x^n = nx^{n-1} $
#
#
# [Latex在线公式网站](https://www.codecogs.com/latex/eqneditor.php?lang=zh-cn)

# %% [markdown]
# ## 三角函数的导数
#
# - (sin x)' = cosx
# - (cos x)' = -sin x
# - $(tan x)' = sec^{2}x$
# - $(cot x)' = -csc^{2}x$
#   > (sec x)(cos x)  =1
#   > (csc x)(sin x)  =1
# - (sec x)' = sec x tan x
# - (csc x)' = - csc x cot x

# %% [markdown]
# ## 指数对数函数的导数
#
# - $(a^{x})' = a^{x}ln a$
# - $ (e^{x})' = e^{x}$
# - $(log_{a}x)' = \frac {1}{x ln a} $
# - $ (ln x)' = \frac {1}{x}$
#
#
#
# > 底为10的对数是常用对数(common logarithm)，记为lg. 底为e的是自然对数(natural logarithm) 记为ln

# %% [markdown]
# ## 反函数的导数
#
#
# - $(arcsin x)' = \frac{1}{\sqrt{1-x^{2}}} $
# - $(arccos x)' = - \frac{1}{\sqrt{1-x^{2}}} $
# - $(arctan x)' = \frac{1}{\sqrt{1+x^{2}}} $
# - $(arccot x)' = - \frac{1}{\sqrt{1+x^{2}}} $

# %% [markdown]
# ## 符合函数的求导法则
#
# 设 y = f(u), u = g(x), 则复合函数 y = f[g(x)]的导数为
#
# y'(x) = f'(u) g'(x)

# %% [markdown]
# ## 什么是全导数、偏导数、方向导数、梯度
#
# ### 全导数
# 随便画一条线，这条线上某个点的切线对应到全导数
#
# ### 偏导数
#
# 平行于x轴和平行于y轴
#
# ### 方向导数
# 投影到XY平面上是一条射线
#
# 偏导数和方向导数的曲线都在一个平面上，拍扁后不会变形，全导数的曲线不在一个平面上，拍扁后会变形
# <img src="images/fangxiangdaoshu.png" width="200px" height="200px" />
# <img src="images/fangxiangdaoshu2.png" width="200px" height="200px" />
# <img src="images/fangxiangdaoshu3.png" width="200px" height="200px" />
#
# $ \Large{\frac {\partial f}{\partial x}
# = \lim_{\rho \rightarrow 0} \frac{f(x_0 + \rho cos\alpha, y_0 + \rho cos \beta) - f(x_0,y_0)}{\rho}} $
#
# 方向导数与偏导数的关系
#
# $\Large{\frac {\partial f}{\partial l}
# = \frac {\partial f}{\partial x} cos \alpha + \frac {\partial f}{\partial y} cos \beta
# }$
#
# 梯度与方向导数的几何解释
#
# <img src="images/tidu1.png" width="300px" height="300px" />
# <img src="images/tidu2.png" width="300px" height="300px" />
#
# ### 梯度
# 表示某一函数在该点处的方向导数沿着该方向取得最大值，即函数在该点处沿着该方向（此梯度的方向）变化最快，变化率最大（为该梯度的模）。
# 梯度垂直于等值线

# %% [markdown]
# # 向量及其线性运算
#
# 向量加法
# <img src="images/xiangliang1.png" width="300px" height="300px" />
#
# 向量结合律
# <img src="images/xiangliang2.png" width="300px" height="300px" />
#
# 向量减法
# <img src="images/xiangliang3.png" width="300px" height="300px" />
#
#
# 加法减法的图形法则
# <img src="images/xiangliang4.png" width="300px" height="300px" />
#
#
# 数乘运算
# <img src="images/xiangliang7.png" width="300px" height="300px" />
#
#
#
# - 向量可以移项
#
#     a = b + c  $\rightarrow $  a - b = c
#
#
# - 一个非零向量可以线性表示与之平行的所有向量
#
#
# - 若 a不平行b，则任何和a,b共面的向量c可以表示为 c = xa + yb
#
#
# - 若a,b,c不共面，则空间中任何向量d都可以表示为 d = xa + yb + zc
#
#
# - 向量坐标
#
# <img src="images/xiangliang8.png" width="300px" height="300px" />

# %% [markdown]
# ## 向量各种关系
#
# <img src="images/xiangliang5.png" width="300px" height="300px" />
#
# <img src="images/xiangliang6.png" width="300px" height="300px" />

# %% [markdown]
# # 坐标系
#
# 平面坐标系
#
# <img src="images/zuobiaoxi1.png" width="300px" height="300px" />
#
#
#
# 空间坐标系
#
# <img src="images/zuobiaoxi2.png" width="300px" height="300px" />

# %% [markdown]
# ## 坐标系各种定理
#
#
# 向量的运算就是分量的运算
#
# <img src="images/zuobiaoxi5.png" width="300px" height="300px" />
#
# 两向量平行的充分条件是它们对应的分量成比例
#
# <img src="images/zuobiaoxi6.png" width="300px" height="300px" />
#
#
# <p style="color:red"> **记忆：终点坐标 - 起点坐标  = 向量坐标** </p>
# <img src="images/zuobiaoxi7.png" width="300px" height="300px" />

# %% [markdown]
# ## 向量计算
#
#
# 向量的模的计算公式
#
# <img src="images/zuobiaoxi8.png" width="300px" height="300px" />
#
# 空间两点间的距离
#
# <img src="images/zuobiaoxi9.png" width="300px" height="300px" />
#
# 向量的单位化
# <img src="images/zuobiaoxi10.png" width="300px" height="300px" />

# %% [markdown]
# ## 方向角和方向余弦
#
# <img src="images/fangxiangjiao1.png" width="300px" height="300px" />
#
#
#
# <img src="images/fangxiangjiao2.png" width="300px" height="300px" />
#
#
#
# <img src="images/fangxiangjiao3.png" width="300px" height="300px" />
#
#
#
# <img src="images/fangxiangjiao4.png" width="300px" height="300px" />
#
#
#
# <img src="images/fangxiangyuxian1.png" width="300px" height="300px" />

# %% [markdown]
# ## 数量积
#
# 数量积
# <img src="images/shuliangji1.png" width="300px" height="300px" />
#
#
# 点积和内积
# <img src="images/shuliangji2.png" width="300px" height="300px" />
#
#
# 投影
#
# <img src="images/shuliangji3.png" width="300px" height="300px" />
#
#
# 投影计算
# <img src="images/shuliangji4.png" width="300px" height="300px" />
#
#
# <img src="images/shuliangji5.png" width="300px" height="300px" />
#
#
# 数量积的运算律
#
# 1. 交换律   a ・ b = b ・ a
# 2. 分配律   (a + b)・c = a・c + b・c
# 3. (ka)・b = k(a・b) = a(k・b)
#
#
# 性质一：
#
# a ・ a  = $|a|^2 = a^2$
#
#
# 性质二：
#
# 两个向量垂直的充要条件是 a ・ b = 0
#
# <p style="color:red">点积任何时候 ・ 不能省掉</p>
#
#
# <img src="images/shuliangji7.png" width="300px" height="300px" />
#
# <img src="images/shuliangji8.png" width="300px" height="300px" />
